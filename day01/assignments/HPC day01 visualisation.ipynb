# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(1,31)

#data depuis Ubunto c++
vect1_O0 = [2652.000000,3015.000000,3268.000000,3656.000000,3996.000000,4651.000000,4736.000000,5230.000000,5866.000000,7693.000000,6487.000000,7473.000000,8064.000000,9782.000000,8400.000000,9757.000000,10328.000000,10548.000000,11745.000000,11472.000000,10026.000000,12637.000000,10787.000000,10742.000000,12547.000000,11121.000000,11073.000000,12653.000000,13942.000000,11452.000000]  
vect2_O0 = [2.876846,2.530479,2.334576,2.086815,1.909258,1.640377,1.610936,1.458775,1.300613,0.991732,1.176105,1.020928,0.946105,0.779942,0.908261,0.781941,0.738710,0.723302,0.649587,0.665045,0.760961,0.603735,0.707277,0.710240,0.608065,0.686035,0.689009,0.602971,0.547224,0.666206]
vect1_O2 = [1390.000000,1534.000000,1613.000000,1906.000000,2350.000000,11609.000000,3275.000000,4095.000000,4423.000000,4239.000000,6250.000000,5434.000000,4978.000000,5347.000000,6124.000000,5588.000000,6344.000000,6690.000000,6091.000000,7693.000000,6873.000000,6722.000000,6548.000000,7006.000000,7911.000000,6856.000000,19419.000000,7203.000000,6778.000000,7517.000000] 
vect2_O2 = [5.488773,4.973530,4.729941,4.002830,3.246551,0.657197,2.329586,1.863100,1.724937,1.799810,1.220703,1.404011,1.532622,1.426855,1.245819,1.365318,1.202616,1.140418,1.252568,0.991732,1.110053,1.134989,1.165149,1.088980,0.964403,1.112806,0.392883,1.059197,1.125611,1.014952]
#affichage 1 

plt.title("Rate cas vecteur")
plt.xlabel("Stride")
plt.ylabel("Rate")
plt.plot(x,vect1_O0,label='Using O0')
plt.plot(x,vect1_O2,label='Using O2')
plt.legend()

# %%
#affichage 2
plt.title("Cpu Time cas vecteur")
plt.xlabel("Stride")
plt.ylabel("CPU Time,ms")
plt.plot(x,vect2_O0,label='Using O0')
plt.plot(x,vect2_O2,label='Using O2')
plt.legend()

# %%
#data depuis Ubunto C++
x = np.arange(1,51)
Rate_02 = [141.050001,147.228764,139.834944,144.770295,149.742778,143.760967,144.277506,146.381323,149.625309,146.578185,147.856483,144.032368,144.059564,142.605505,150.096292,145.155908,145.571351,145.738195,145.294126,145.488073,145.626924,145.515822,145.460334,146.073033,145.183531,144.578255,145.961250,146.213004,145.349486,145.515822,145.515822,144.935306,146.156983,146.521885,144.578255,145.710362,145.515822,144.935306,146.269067,146.297115,145.543581,145.073104,145.404889,145.045523,145.738195,145.682538,145.710362,146.017120,145.599132,144.550863] 
CPU_Time_02 = [5.409000,5.182000,5.456000,5.270000,5.095000,5.307000,5.288000,5.212000,5.099000,5.205000,5.160000,5.297000,5.296000,5.350000,5.083000,5.256000,5.241000,5.235000,5.251000,5.244000,5.239000,5.243000,5.245000,5.223000,5.255000,5.277000,5.227000,5.218000,5.249000,5.243000,5.243000,5.264000,5.220000,5.207000,5.277000,5.236000,5.243000,5.264000,5.216000,5.215000,5.242000,5.259000,5.247000,5.260000,5.235000,5.237000,5.236000,5.225000,5.240000,5.278000]
Rate_00 = [53.468320,51.563899,52.088445,52.747473,52.948813,53.051906,52.794924,53.251864,52.435701,53.505818,52.587500,52.919432,52.791271,52.948813,52.794924,52.641927,52.674638,52.580252,52.627402,52.930446,53.015041,52.923103,52.970871,52.414087,52.747473,52.945139,52.714672,52.652826,52.587500,47.683716,50.529138,52.816854,52.700107,52.006779,53.074049,52.460940,52.912092,50.673449,52.901085,52.919432,52.396089,52.959840,52.908423,52.871757,52.791271,52.952488,52.802232,52.827825,52.835142,52.886417] 
CPU_Time_00 = [14.269000,14.796000,14.647000,14.464000,14.409000,14.381000,14.451000,14.327000,14.550000,14.259000,14.508000,14.417000,14.452000,14.409000,14.451000,14.493000,14.484000,14.510000,14.497000,14.414000,14.391000,14.416000,14.403000,14.556000,14.464000,14.410000,14.473000,14.490000,14.508000,16.000000,15.099000,14.445000,14.477000,14.670000,14.375000,14.543000,14.419000,15.056000,14.422000,14.417000,14.561000,14.406000,14.420000,14.430000,14.452000,14.408000,14.449000,14.442000,14.440000,14.426000]

# %%
#affichage 3 

plt.title("Rate cas Matrice")
plt.xlabel("Stride")
plt.ylabel("Rate")
plt.plot(x,Rate_02 ,label='Using O2')
plt.legend()

# %%
plt.title("Rate cas Matrice")
plt.xlabel("Stride")
plt.ylabel("Rate")
plt.plot(x,Rate_00,label='Using O0',color ='red')
plt.legend()

# %%
#affichage 4
plt.title("Cpu Time cas Matrice")
plt.xlabel("Stride")
plt.ylabel("CPU Time,ms")
plt.plot(x,CPU_Time_02,label='Using O2')
plt.legend()

# %%
#affichage 4
plt.title("Cpu Time cas Matrice")
plt.xlabel("Stride")
plt.ylabel("CPU Time,ms")
plt.plot(x,CPU_Time_00,label='Using O0',color ='red')
plt.legend()

# %%
#data depuis windows C++

# %%
x = np.arange(1,31)
Rate_02 = [82.036499,80.309418,79.472862,82.036499,82.036499,82.928200,81.163773,82.928200,82.036499,82.928200,82.928200,82.928200,82.928200,82.036499,82.928200,81.163773,83.839500,82.928200,82.928200,83.839500,82.036499,82.928200,83.839500,82.928200,82.928200,82.928200,82.928200,82.928200,82.928200,82.928200]
CPU_Time_02 = [93.000000,93.000000,93.000000,93.000000,92.000000,92.000000,94.000000,93.000000,91.000000,93.000000,93.000000,91.000000,92.000000,92.000000,92.000000,92.000000,91.000000,92.000000,93.000000,92.000000,93.000000,93.000000,92.000000,92.000000,92.000000,93.000000,93.000000,94.000000,91.000000,94.000000,]

# %%
plt.title("Rate cas Matrice")
plt.xlabel("Stride")
plt.ylabel("Rate")
plt.plot(x,Rate_02 ,label='Using O2 Windows')
plt.legend()

# %%
plt.title("Rate cas Matrice")
plt.xlabel("Stride")
plt.ylabel("Rate")
plt.plot(x,CPU_Time_02 ,label='Using O2 Windows')
plt.legend()
